# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/.../tiktok_dataset.csv')

# %%
df.head()
# Out:
#    # claim_status    video_id  video_duration_sec  \
# 0  1        claim  7017666017                  59
# 1  2        claim  4014381136                  32
# 2  3        claim  9859838091                  31
# 3  4        claim  1866847991                  25
# 4  5        claim  7105231098                  19
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# 4  someone shared with me that the number of busi...    not verified
#
#   author_ban_status  video_view_count  video_like_count  video_share_count  \
# 0      under review          343296.0           19425.0              241.0
# 1            active          140877.0           77355.0            19034.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %%
df.describe()
# Out:
#                   #      video_id  video_duration_sec  video_view_count  \
# count  19382.000000  1.938200e+04        19382.000000      19084.000000
# mean    9691.500000  5.627454e+09           32.421732     254708.558688
# std     5595.245794  2.536440e+09           16.229967     322893.280814
# min        1.000000  1.234959e+09            5.000000         20.000000
# 25%     4846.250000  3.430417e+09           18.000000       4942.500000
# 50%     9691.500000  5.618664e+09           32.000000       9954.500000
# 75%    14536.750000  7.843960e+09           47.000000     504327.000000
# max    19382.000000  9.999873e+09           60.000000     999817.000000
#
#        video_like_count  video_share_count  video_download_count  \
# count      19084.000000       19084.000000          19084.000000
# mean       84304.636030       16735.248323           1049.429627
# std       133420.546814       32036.174350           2004.299894
# ...

# %%
df.size
# Out:
# 232584

# %%
# Create a boxplot of video duration sec column

plt.figure(figsize = (10, 3))
ax1 = sns.boxplot(x = df['video_duration_sec'], fliersize = 1)

# %%
# Create a histogram of video duration sec

plt.figure(figsize = (12, 5))
ax2 = sns.histplot(x = df['video_duration_sec'], bins = range(5,65,5))

# %%
# Create a boxplot of video view count column

plt.figure(figsize = (10, 3))
ax3 = sns.boxplot(x = df['video_view_count'], fliersize = 1)

# %%
# Create a histogram of video view count

plt.figure(figsize = (12, 5))
ax4 = sns.histplot(x = df['video_view_count'], bins = range(20,10**6,10**5))

# %%
# Create a box plot for video like count
plt.figure(figsize = (10,3))
ax5 = sns.boxplot(x = df['video_like_count'], fliersize = 1)

# %%
# Create a histogram for video like count

plt.figure(figsize = (12,5))
ax6 = sns.histplot(x = df['video_like_count'], bins = range(0, 7*10**5,10**5))
labels = [0] + [str(i) + 'k' for i in range(100,700,100)]
ax6.set_xticks(range(0, 7*10**5,10**5), labels = labels)
plt.title('The histogram of video like count')
plt.xlabel('Video like')
# Out:
# Text(0.5, 0, 'Video like')

# %%
# Create a box plot of video comment count

plt.figure(figsize = (5,3))
ax7 = sns.boxplot(x = df['video_comment_count'], fliersize = 1)

# %%
# Create a histogram of video comment count

plt.figure(figsize = (7,4))
ax8 = sns.histplot(x = df['video_comment_count'], bins = range(0,10**4 + 1,10**3))
plt.xlabel('Video comment')
plt.title('The histogram of video comment count')
# Out:
# Text(0.5, 1.0, 'The histogram of video comment count')

# %%
# Box plot of video share count

plt.figure(figsize = (5,3))
ax9 = sns.boxplot(x = df['video_share_count'], fliersize = 1)

# %%
# Histogram of video share count

plt.figure(figsize = (12,5))
ax10 = sns.histplot(x = df['video_share_count'], bins = range(0, 27*10**4 + 1, 10**4))

# %%
# Boxplot of video download count

plt.figure(figsize=(5,3))
ax11 = sns.boxplot(x = df['video_download_count'], fliersize = 1)

# %%
# Histogram of video download count

plt.figure(figsize = (12, 5))
ax12 = sns.histplot(x = df['video_download_count'], bins = range(0, 15*10**3 + 1, 10**3))

# %%
# Examine the count of video group by each claim status and  each verified status
claim_verified_group = df.groupby(['claim_status','verified_status'])['video_id'].count().reset_index()
claim_verified_group = claim_verified_group.rename(columns = {'video_id' : 'count_video'})
claim_verified_group
# Out:
#   claim_status verified_status  count_video
# 0        claim    not verified         9399
# 1        claim        verified          209
# 2      opinion    not verified         8485
# 3      opinion        verified          991

# %%
# create a histogram with four bars: one for each combination of claim status and verification status

plt.figure(figsize = (7,5))
ax13 = sns.histplot(data = df, x = 'claim_status',
                    hue = 'verified_status',
                    multiple = 'dodge',
                    shrink = 0.9)
plt.title('The histogram for each combination of claim status and verification status')
# Out:
# Text(0.5, 1.0, 'The histogram for each combination of claim status and verification status')

# %% [markdown]
# *- There are far fewer verified users than unverified users, but if a user is verified, they are much more likely to post opinions.*
#
#
# ---

# %%
# Examine the video count group by each claim status and each author ban status

plt.figure(figsize = (7,5))
ax14 = sns.histplot(data = df, x = 'claim_status',
                    hue = 'author_ban_status',
                    hue_order = ['active', 'under review', 'banned'],
                    multiple = 'dodge',
                    shrink = 0.9,
                    palette = {'active':'green', 'under review':'orange', 'banned':'red'})
plt.title('Examine the video count group by each claim status and each author ban status')
# Out:
# Text(0.5, 1.0, 'Examine the video count group by each claim status and each author ban status')

# %% [markdown]
# *- For both claims and opinions, there are many more active authors than banned authors or authors under review; however, the proportion of active authors is far greater for opinion videos than for claim videos. Again, it seems that authors who post claim videos are more likely to come under review and/or get banned.*
#
#
# ---

# %%
# Examine median view count for each author ban status

med_view_by_author_status = df.groupby('author_ban_status')['video_view_count'].median().reset_index()
med_view_by_author_status
# Out:
#   author_ban_status  video_view_count
# 0            active            8616.0
# 1            banned          448201.0
# 2      under review          365245.5

# %%
# Bar plot for median view corresponding to each author ban status

plt.figure(figsize = (7, 5))
ax15 = sns.barplot(data = med_view_by_author_status, x = 'author_ban_status',
                   y = 'video_view_count',
                   palette = {'active':'green', 'under review':'orange', 'banned':'red'},
                   order = ['active', 'under review', 'banned'])
plt.ylabel('Median view count')
plt.xlabel('Author ban status')
plt.title('Median view count by ban status')
# Out:
# Text(0.5, 1.0, 'Median view count by ban status')

# %% [markdown]
# *- The median view counts for non-active authors are many times greater than the median view count for active authors. Since we know that non-active authors are more likely to post claims, and that videos by non-active authors get far more views on aggregate than videos by active authors, then 'video_view_count' might be a good indicator of claim status.*
#
#
# ---

# %%
# Examine the median view count by each claim status

med_view_by_claim_status = df.groupby('claim_status')['video_view_count'].median().reset_index()
med_view_by_claim_status
# Out:
#   claim_status  video_view_count
# 0        claim          501555.0
# 1      opinion            4953.0

# %%
# Create a pie chart to show the propotion of claim and opinion videos

plt.figure(figsize = (4,4))
plt.pie(df.groupby('claim_status')['video_view_count'].sum(), labels = ['claim','opinion'])
plt.title('The propotion of claim and opinion videos in dataset.')
# Out:
# Text(0.5, 1.0, 'The propotion of claim and opinion videos in dataset.')

# %% [markdown]
# *- The overall view count is dominated by claim videos even though there are roughly the same number of each video in the dataset.*
#
#
# ---

# %% [markdown]
# **Calculate the outliers for each column and visualize scatter plots**

# %%
# Calculate the outliers

df_cols = ['video_view_count',
           'video_like_count',
           'video_share_count',
           'video_download_count',
           'video_comment_count']

for column in df_cols:
  q1 = df[column].quantile(0.25)
  q3 = df[column].quantile(0.75)
  iqr = q3 - q1

  median = df[column].median()

  outliers_threshold = median + 1.5*iqr

  exceed_count = (df[column] > outliers_threshold).sum()

  print('Number of outliers, {0}: {1}'.format(column, exceed_count))
# Out:
# Number of outliers, video_view_count: 2343
# Number of outliers, video_like_count: 3468
# Number of outliers, video_share_count: 3732
# Number of outliers, video_download_count: 3733
# Number of outliers, video_comment_count: 3882

# %%
# Create a scatter plot between video view count and video like count corresponding to claim status

plt.figure(figsize = (7,3))
ax16 = sns.scatterplot(data = df, x = 'video_view_count', y = 'video_like_count', hue = 'claim_status')
plt.title('Video like count versus video view count')
# Out:
# Text(0.5, 1.0, 'Video like count versus video view count')

# %%
# Create a scatter plot for `video_view_count` versus `video_like_count` for opinions only

df_opinion = df[df['claim_status'] == 'opinion']
plt.figure(figsize = (7,3))
ax17 = sns.scatterplot(data = df_opinion, x = 'video_view_count', y = 'video_like_count')
plt.title('Video like count versus video view count for opinion only')
# Out:
# Text(0.5, 1.0, 'Video like count versus video view count for opinion only')
